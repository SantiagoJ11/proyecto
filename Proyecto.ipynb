# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoJ11/proyecto/blob/master/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install django
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 41.3 MB/s eta 0:00:00
# ...

# %%
# !django-admin startproject santiagojaimes

# %%
# %cd /content/santiagojaimes/
# Out:
# /content/santiagojaimes

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://t4k3romuwr-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# !python manage.py runserver
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 18 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): admin, auth, contenttypes, sessions.
# Run 'python manage.py migrate' to apply them.
# April 24, 2023 - 13:41:12
# Django version 4.2, using settings 'santiagojaimes.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
#
# [24/Apr/2023 13:42:05] "GET /edad/2030 HTTP/1.1" 200 44
# Not Found: /favicon.ico
# [24/Apr/2023 13:42:05] "GET /favicon.ico HTTP/1.1" 404 2462
# Not Found: /
# [24/Apr/2023 13:43:25] "GET / HTTP/1.1" 404 2411
# /content/santiagojaimes/edad/urls.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# ...

# %%
# !python manage.py startapp edad

# %%
# !python manage.py startapp fecha

# %%
# !python manage.py startapp polls
